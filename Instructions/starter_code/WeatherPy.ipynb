# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 612

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#bring in url for weather map and API
url = "http://api.openweathermap.org/data/2.5/weather?units= imperial&appid=" + api_key

#make a list to hold the data
city_data = []
#create a counter
counter = 0
#create a loop to go through the cities from the unique condition
for city in cities:
    #combine the city name to the url
    city_url = url + "&q=" + city
    #print city counter
    print(f"Processing {counter} | {city}")
    
    counter = counter +1
    #get city info in JSON format
    city_wx = requests.get(city_url).json()
    
    #create a dictionary with pertinant data to live in the list
    city_data.append({"City":city, 
                     "Lat": city_lat
                     "Lng": city_lng
                     "Max Temp": city_max_temp, 
                     "Humidity": city_humidity, 
                     "Cloudiness": city_clds, 
                     "Wind Speed": city_wnds, 
                     "Country": Country, 
                     "Date": city_date})
# Out:
# Processing 0 | yagodnoye
# Processing 1 | farafangana
# Processing 2 | hamilton
# Processing 3 | amderma
# Processing 4 | busselton
# Processing 5 | albany
# Processing 6 | hermanus
# Processing 7 | troyes
# Processing 8 | kaduqli
# Processing 9 | atuona
# Processing 10 | kruisfontein
# Processing 11 | norman wells
# Processing 12 | arraial do cabo
# Processing 13 | alice springs
# Processing 14 | paamiut
# Processing 15 | rungata
# Processing 16 | pangnirtung
# Processing 17 | katobu
# Processing 18 | ushuaia
# Processing 19 | aripuana
# Processing 20 | barentsburg
# Processing 21 | phan rang
# Processing 22 | butaritari
# Processing 23 | oksfjord
# Processing 24 | punta arenas
# Processing 25 | avarua
# Processing 26 | yefimovskiy
# Processing 27 | kaitangata
# Processing 28 | tual
# Processing 29 | mataura
# Processing 30 | chuy
# Processing 31 | castro
# Processing 32 | jamestown
# Processing 33 | rikitea
# Processing 34 | mbanza-ngungu
# Processing 35 | jadu
# Processing 36 | nome
# Processing 37 | karasburg
# Processing 38 | codrington
# Processing 39 | vaini
# Processing 40 | san rafael
# Processing 41 | vao
# Processing 42 | puerto ayora
# Processing 43 | tiksi
# Processing 44 | babushkin
# Processing 45 | havelock
# Processing 46 | tukrah
# Processing 47 | saskylakh
# Processing 48 | hilo
# Processing 49 | richards bay
# Processing 50 | faanui
# Processing 51 | kodiak
# Processing 52 | saint-pierre
# Processing 53 | ganzhou
# Processing 54 | luderitz
# Processing 55 | mar del plata
# Processing 56 | dingle
# Processing 57 | tasiilaq
# Processing 58 | khatanga
# Processing 59 | grand gaube
# Processing 60 | taolanaro
# Processing 61 | zhanaozen
# Processing 62 | solnechnyy
# Processing 63 | juneau
# Processing 64 | rognan
# Processing 65 | bethel
# Processing 66 | dikson
# Processing 67 | saint george
# Processing 68 | wewak
# Processing 69 | esna
# Processing 70 | sioux lookout
# Processing 71 | lompoc
# Processing 72 | oranjemund
# Processing 73 | ketchikan
# Processing 74 | kumluca
# Processing 75 | tateyama
# Processing 76 | kamenka
# Processing 77 | eldorado
# Processing 78 | beni
# Processing 79 | north platte
# Processing 80 | monmouth
# Processing 81 | east london
# Processing 82 | mitrofanovka
# Processing 83 | bredasdorp
# Processing 84 | bluff
# Processing 85 | morro bay
# Processing 86 | adrar
# Processing 87 | skjervoy
# Processing 88 | new norfolk
# Processing 89 | ugoofaaru
# Processing 90 | phan thiet
# Processing 91 | qaanaaq
# Processing 92 | severo-kurilsk
# Processing 93 | masallatah
# Processing 94 | kavieng
# Processing 95 | georgetown
# Processing 96 | bonga
# Processing 97 | hasaki
# Processing 98 | nago
# Processing 99 | rio de janeiro
# Processing 100 | namibe
# Processing 101 | port elizabeth
# Processing 102 | nuuk
# Processing 103 | bud
# Processing 104 | alofi
# Processing 105 | sur
# Processing 106 | poum
# Processing 107 | sentyabrskiy
# Processing 108 | saldanha
# Processing 109 | thiruvananthapuram
# Processing 110 | joshimath
# Processing 111 | port hardy
# Processing 112 | ambodifototra
# Processing 113 | varna
# Processing 114 | kragero
# Processing 115 | longyearbyen
# Processing 116 | inta
# Processing 117 | tura
# Processing 118 | partenit
# Processing 119 | praia da vitoria
# Processing 120 | kahului
# Processing 121 | maarianhamina
# Processing 122 | weston
# Processing 123 | dunedin
# Processing 124 | hobart
# Processing 125 | lasa
# Processing 126 | koutiala
# Processing 127 | makakilo city
# Processing 128 | mecca
# Processing 129 | cape town
# Processing 130 | carlsbad
# Processing 131 | bursol
# Processing 132 | mahebourg
# Processing 133 | dakoro
# Processing 134 | cherskiy
# Processing 135 | kapaa
# Processing 136 | victoria
# Processing 137 | deputatskiy
# Processing 138 | illoqqortoormiut
# Processing 139 | egvekinot
# Processing 140 | laja
# Processing 141 | uusikaupunki
# Processing 142 | revelstoke
# Processing 143 | aklavik
# Processing 144 | nushki
# Processing 145 | lata
# Processing 146 | san miguel
# Processing 147 | katsuura
# Processing 148 | port-gentil
# Processing 149 | esperance
# Processing 150 | kamaishi
# Processing 151 | belushya guba
# Processing 152 | hualmay
# Processing 153 | hambantota
# Processing 154 | pingliang
# Processing 155 | oyama
# Processing 156 | ayorou
# Processing 157 | bay roberts
# Processing 158 | belaya gora
# Processing 159 | porto walter
# Processing 160 | thompson
# Processing 161 | tessalit
# Processing 162 | raudeberg
# Processing 163 | ixtapa
# Processing 164 | yeppoon
# Processing 165 | san cristobal
# Processing 166 | surt
# Processing 167 | barrow
# Processing 168 | roma
# Processing 169 | garut
# Processing 170 | saleaula
# Processing 171 | ponta do sol
# Processing 172 | pontalina
# Processing 173 | stokmarknes
# Processing 174 | tuktoyaktuk
# Processing 175 | bengkulu
# Processing 176 | trelew
# Processing 177 | san patricio
# Processing 178 | petatlan
# Processing 179 | doctor pedro p. pena
# Processing 180 | nuevo progreso
# Processing 181 | nea fokaia
# Processing 182 | provideniya
# Processing 183 | pevek
# Processing 184 | usinsk
# Processing 185 | kudat
# Processing 186 | krasnovishersk
# Processing 187 | jiaozuo
# Processing 188 | husavik
# Processing 189 | haines junction
# Processing 190 | mahibadhoo
# Processing 191 | pangody
# Processing 192 | beneditinos
# Processing 193 | fortuna
# Processing 194 | bathsheba
# Processing 195 | nikolskoye
# Processing 196 | cockburn town
# Processing 197 | zhaoyuan
# Processing 198 | upernavik
# Processing 199 | marinette
# Processing 200 | lukovetskiy
# Processing 201 | fort nelson
# Processing 202 | buchanan
# Processing 203 | college
# Processing 204 | sitka
# Processing 205 | faya
# Processing 206 | camopi
# Processing 207 | huarmey
# Processing 208 | tete
# Processing 209 | geraldton
# Processing 210 | ancud
# Processing 211 | la ronge
# Processing 212 | nizhneyansk
# Processing 213 | grand river south east
# Processing 214 | mairang
# Processing 215 | samusu
# Processing 216 | dwarka
# Processing 217 | davila
# Processing 218 | nanortalik
# Processing 219 | tambo
# Processing 220 | lavrentiya
# Processing 221 | bridlington
# Processing 222 | shimoda
# Processing 223 | nelson bay
# Processing 224 | douentza
# Processing 225 | sao miguel do araguaia
# Processing 226 | chitungwiza
# Processing 227 | mehamn
# Processing 228 | fairbanks
# Processing 229 | olinda
# Processing 230 | yellowknife
# Processing 231 | huron
# Processing 232 | kaihua
# Processing 233 | moree
# Processing 234 | cimarron hills
# Processing 235 | druzhba
# Processing 236 | ryzdvyanyy
# Processing 237 | nalut
# Processing 238 | katherine
# Processing 239 | te anau
# Processing 240 | saint-philippe
# Processing 241 | saint-francois
# Processing 242 | cockburn harbour
# Processing 243 | redmond
# Processing 244 | cidreira
# Processing 245 | prince rupert
# Processing 246 | mount isa
# Processing 247 | lebu
# Processing 248 | ribeira grande
# Processing 249 | sao mateus do sul
# Processing 250 | oranjestad
# Processing 251 | severo-yeniseyskiy
# Processing 252 | hithadhoo
# Processing 253 | vostok
# Processing 254 | guiratinga
# Processing 255 | stekolnyy
# Processing 256 | olafsvik
# Processing 257 | narsaq
# Processing 258 | port augusta
# Processing 259 | ponta delgada
# Processing 260 | humaita
# Processing 261 | khandbari
# Processing 262 | port alfred
# Processing 263 | puerto escondido
# Processing 264 | vinderup
# Processing 265 | peniche
# Processing 266 | ahipara
# Processing 267 | buraydah
# Processing 268 | artyk
# Processing 269 | broken hill
# Processing 270 | matamoros
# Processing 271 | atbasar
# Processing 272 | asau
# Processing 273 | zhaocheng
# Processing 274 | omsukchan
# Processing 275 | debre birhan
# Processing 276 | canitas
# Processing 277 | ximei
# Processing 278 | quzhou
# Processing 279 | tigil
# Processing 280 | qaqortoq
# Processing 281 | torrington
# Processing 282 | kenai
# Processing 283 | baykit
# Processing 284 | miguel calmon
# Processing 285 | iqaluit
# Processing 286 | rawson
# Processing 287 | airai
# Processing 288 | saint-joseph
# Processing 289 | hermiston
# Processing 290 | khasan
# Processing 291 | mnogovershinnyy
# Processing 292 | kudahuvadhoo
# Processing 293 | sao filipe
# Processing 294 | attawapiskat
# Processing 295 | touros
# Processing 296 | rundu
# Processing 297 | maykain
# Processing 298 | hofn
# Processing 299 | torbay
# Processing 300 | opuwo
# Processing 301 | sao joao da barra
# Processing 302 | helong
# Processing 303 | tsihombe
# Processing 304 | yenagoa
# Processing 305 | bodden town
# Processing 306 | kurkino
# Processing 307 | isangel
# Processing 308 | payson
# Processing 309 | wangqing
# Processing 310 | cabo san lucas
# Processing 311 | ulladulla
# Processing 312 | klaksvik
# Processing 313 | tumannyy
# Processing 314 | kathmandu
# Processing 315 | cayenne
# Processing 316 | uruguaiana
# Processing 317 | gongzhuling
# Processing 318 | coquimbo
# Processing 319 | corleone
# Processing 320 | penarroya-pueblonuevo
# Processing 321 | kimbe
# Processing 322 | sola
# Processing 323 | portland
# Processing 324 | kirakira
# Processing 325 | ekibastuz
# Processing 326 | zhangzhou
# Processing 327 | souillac
# Processing 328 | okhotsk
# Processing 329 | carnarvon
# Processing 330 | chokurdakh
# Processing 331 | eucaliptus
# Processing 332 | loubomo
# Processing 333 | fort frances
# Processing 334 | erenhot
# Processing 335 | svetlaya
# Processing 336 | pacific grove
# Processing 337 | bilibino
# Processing 338 | nador
# Processing 339 | llanes
# Processing 340 | namatanai
# Processing 341 | andra
# Processing 342 | carora
# Processing 343 | sluknov
# Processing 344 | san jose
# Processing 345 | harper
# Processing 346 | vardo
# Processing 347 | lagoa
# Processing 348 | nong chik
# Processing 349 | ndele
# Processing 350 | marawi
# Processing 351 | ilulissat
# Processing 352 | yumen
# Processing 353 | naze
# Processing 354 | aloleng
# Processing 355 | bulihan
# Processing 356 | kamphaeng phet
# Processing 357 | shchelyayur
# Processing 358 | ilo
# Processing 359 | lamu
# Processing 360 | muncar
# Processing 361 | hit
# Processing 362 | ostrovnoy
# Processing 363 | urengoy
# Processing 364 | danjiangkou
# Processing 365 | talnakh
# Processing 366 | halalo
# Processing 367 | narasingapuram
# Processing 368 | novobataysk
# Processing 369 | gazanjyk
# Processing 370 | guantanamo
# Processing 371 | panorama
# Processing 372 | kuching
# Processing 373 | divo
# Processing 374 | vanavara
# Processing 375 | yerofey pavlovich
# Processing 376 | coahuayana
# Processing 377 | muros
# Processing 378 | san ignacio
# Processing 379 | salalah
# Processing 380 | christchurch
# Processing 381 | yuxia
# Processing 382 | komsomolskiy
# Processing 383 | meyungs
# Processing 384 | koumac
# Processing 385 | rocha
# Processing 386 | yashkul
# Processing 387 | carballo
# Processing 388 | hervey bay
# Processing 389 | palmer
# Processing 390 | benghazi
# Processing 391 | bakel
# Processing 392 | kamenskoye
# Processing 393 | bonthe
# Processing 394 | port hedland
# Processing 395 | atiquizaya
# Processing 396 | sinkat
# Processing 397 | batticaloa
# Processing 398 | hirara
# Processing 399 | sisimiut
# Processing 400 | zonguldak
# Processing 401 | atar
# Processing 402 | paragominas
# Processing 403 | havre-saint-pierre
# Processing 404 | moa
# Processing 405 | coihaique
# Processing 406 | waipawa
# Processing 407 | bandarbeyla
# Processing 408 | iracoubo
# Processing 409 | san juan de la maguana
# Processing 410 | road town
# Processing 411 | ambilobe
# Processing 412 | elda
# Processing 413 | vaitupu
# Processing 414 | shugurovo
# Processing 415 | necochea
# Processing 416 | calama
# Processing 417 | kattivakkam
# Processing 418 | sadasivpet
# Processing 419 | chokwe
# Processing 420 | rafaela
# Processing 421 | decatur
# Processing 422 | pimenteiras
# Processing 423 | chapais
# Processing 424 | balkhash
# Processing 425 | lorengau
# Processing 426 | acapulco
# Processing 427 | lagos
# Processing 428 | bafq
# Processing 429 | tianpeng
# Processing 430 | toliary
# Processing 431 | nizhnetroitskiy
# Processing 432 | ara
# Processing 433 | biggar
# Processing 434 | mys shmidta
# Processing 435 | palabuhanratu
# Processing 436 | kutum
# Processing 437 | aquiraz
# Processing 438 | miles city
# Processing 439 | haibowan
# Processing 440 | salekhard
# Processing 441 | karamay
# Processing 442 | rawannawi
# Processing 443 | saint-leu
# Processing 444 | seoul
# Processing 445 | saint anthony
# Processing 446 | doka
# Processing 447 | leshukonskoye
# Processing 448 | mount gambier
# Processing 449 | saint-denis
# Processing 450 | yulara
# Processing 451 | kavaje
# Processing 452 | broome
# Processing 453 | copiapo
# Processing 454 | shubarshi
# Processing 455 | zhigansk
# Processing 456 | tilichiki
# Processing 457 | hobyo
# Processing 458 | north bend
# Processing 459 | marcona
# Processing 460 | crotone
# Processing 461 | leningradskiy
# Processing 462 | poladpur
# Processing 463 | abaza
# Processing 464 | jever
# Processing 465 | fort-shevchenko
# Processing 466 | alyangula
# Processing 467 | tall kayf
# Processing 468 | manokwari
# Processing 469 | huilong
# Processing 470 | shashi
# Processing 471 | lons-le-saunier
# Processing 472 | barranca
# Processing 473 | lakselv
# Processing 474 | mandalgovi
# Processing 475 | vestmannaeyjar
# Processing 476 | sal rei
# Processing 477 | luganville
# Processing 478 | kununurra
# Processing 479 | ouegoa
# Processing 480 | mogadishu
# Processing 481 | ventspils
# Processing 482 | netrakona
# Processing 483 | tsabong
# Processing 484 | shieli
# Processing 485 | sinnamary
# Processing 486 | zachagansk
# Processing 487 | kiunga
# Processing 488 | menongue
# Processing 489 | mackay
# Processing 490 | kayerkan
# Processing 491 | roald
# Processing 492 | lichuan
# Processing 493 | vrsac
# Processing 494 | baker city
# Processing 495 | hailey
# Processing 496 | cabra
# Processing 497 | grindavik
# Processing 498 | samalaeulu
# Processing 499 | ambon
# Processing 500 | statesboro
# Processing 501 | primorka
# Processing 502 | tyup
# Processing 503 | moose factory
# Processing 504 | araouane
# Processing 505 | coos bay
# Processing 506 | camacha
# Processing 507 | sungaipenuh
# Processing 508 | umzimvubu
# Processing 509 | campbell river
# Processing 510 | sambava
# Processing 511 | usogorsk
# Processing 512 | jian
# Processing 513 | todos santos
# Processing 514 | edson
# Processing 515 | ajdabiya
# Processing 516 | korla
# Processing 517 | ouadda
# Processing 518 | biltine
# Processing 519 | dubovyy umet
# Processing 520 | konch
# Processing 521 | lake charles
# Processing 522 | hereford
# Processing 523 | barra patuca
# Processing 524 | guerrero negro
# Processing 525 | nizhniy kuranakh
# Processing 526 | gangakher
# Processing 527 | lahat
# Processing 528 | corinto
# Processing 529 | taitung
# Processing 530 | biak
# Processing 531 | presidencia roque saenz pena
# Processing 532 | central point
# Processing 533 | antalaha
# Processing 534 | uthal
# Processing 535 | koslan
# Processing 536 | bambous virieux
# Processing 537 | kismayo
# Processing 538 | kerrville
# Processing 539 | bryan
# Processing 540 | kurilsk
# Processing 541 | ojinaga
# Processing 542 | san policarpo
# Processing 543 | wageningen
# Processing 544 | garca
# Processing 545 | tuggurt
# Processing 546 | avera
# Processing 547 | sawakin
# Processing 548 | toftir
# Processing 549 | blonduos
# Processing 550 | bac lieu
# Processing 551 | nadym
# Processing 552 | aquin
# Processing 553 | izumo
# Processing 554 | severodvinsk
# Processing 555 | henties bay
# Processing 556 | tuatapere
# Processing 557 | talagang
# Processing 558 | kirkwood
# Processing 559 | astoria
# Processing 560 | pavilosta
# Processing 561 | vanimo
# Processing 562 | balabac
# Processing 563 | aswan
# Processing 564 | aksu
# Processing 565 | apatou
# Processing 566 | barawe
# Processing 567 | baillif
# Processing 568 | urumqi
# Processing 569 | el faiyum
# Processing 570 | hay river
# Processing 571 | gryazovets
# Processing 572 | sao felix do xingu
# Processing 573 | general pico
# Processing 574 | almaznyy
# Processing 575 | miasskoye
# Processing 576 | safwah
# Processing 577 | galesong
# Processing 578 | saginaw
# Processing 579 | metro
# Processing 580 | basey
# Processing 581 | taoudenni
# Processing 582 | dukat
# Processing 583 | erzin
# Processing 584 | kuressaare
# Processing 585 | bardiyah
# Processing 586 | ankang
# Processing 587 | flinders
# Processing 588 | madang
# Processing 589 | cap malheureux
# Processing 590 | hami
# Processing 591 | hanahan
# Processing 592 | pocone
# Processing 593 | at-bashi
# Processing 594 | lahan
# Processing 595 | emba
# Processing 596 | kariba
# Processing 597 | pacifica
# Processing 598 | darhan
# Processing 599 | seda
# Processing 600 | nguiu
# Processing 601 | port lincoln
# Processing 602 | lamar
# Processing 603 | itapirapua
# Processing 604 | dutlwe
# Processing 605 | maumere
# Processing 606 | moerai
# Processing 607 | padilla
# Processing 608 | sfantu gheorghe
# Processing 609 | kirkland lake
# Processing 610 | zhanakorgan
# Processing 611 | honningsvag

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot
